# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\Class_Winequality.csv" , sep = (";"))

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.duplicated().any()
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data.skew()
# Out:
# fixed acidity           0.696100
# volatile acidity        1.641081
# citric acid             1.310601
# residual sugar          1.333639
# chlorides               4.969076
# free sulfur dioxide     1.566680
# total sulfur dioxide    0.456800
# density                 1.273318
# pH                      0.455457
# sulphates               0.937853
# alcohol                 0.450697
# quality                 0.112004
# dtype: float64

# %%
data.kurtosis()
# Out:
# fixed acidity            2.253047
# volatile acidity         5.327754
# citric acid              6.844808
# residual sugar           5.681512
# chlorides               35.530288
# free sulfur dioxide     13.434025
# total sulfur dioxide     0.735258
# density                 14.184892
# pH                       0.549957
# sulphates                1.565021
# alcohol                 -0.695980
# quality                  0.299345
# dtype: float64

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    3961.000000       3961.000000  3961.000000     3961.000000
# mean        6.839346          0.280538     0.334332        5.914819
# std         0.866860          0.103437     0.122446        4.861646
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.260000     0.320000        4.700000
# 75%         7.300000          0.330000     0.390000        8.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  3961.000000          3961.000000           3961.000000  3961.000000
# mean      0.045905            34.889169            137.193512     0.993790
# std       0.023103            17.210021             43.129065     0.002905
# ...

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.019214     0.298959
# volatile acidity          -0.019214          1.000000    -0.163228
# citric acid                0.298959         -0.163228     1.000000
# residual sugar             0.083620          0.098340     0.106269
# chlorides                  0.024036          0.086287     0.132590
# free sulfur dioxide       -0.058396         -0.102471     0.091681
# total sulfur dioxide       0.082425          0.102315     0.122845
# density                    0.266091          0.060603     0.160076
# pH                        -0.431274         -0.046954    -0.183015
# sulphates                 -0.017453         -0.021150     0.049442
# alcohol                   -0.110788          0.046815    -0.076514
# quality                   -0.124636         -0.190678     0.007065
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize = (19,8))
sn.boxplot(data)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (19,8))
sn.heatmap(data.corr() , annot = True)
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
for i in ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']:
    sn.distplot(data[i], color = 'red')
    plt.title(i)
    plt.grid()
    plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22772\1438410341.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(data[i], color = 'red')
# C:\Users\user\AppData\Local\Temp\ipykernel_22772\1438410341.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sn.scatterplot(x = "alcohol" , y = "quality", data = data , color = 'red')
# Out:
# <Axes: xlabel='alcohol', ylabel='quality'>

# %%
from scipy import stats

# %%
for i in ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']:
    stats.probplot(data[i] , plot = plt)
    plt.title(i)
    plt.grid()
    plt.show()

# %%
q1 = data.quantile(0.25)
q3 = data.quantile(0.75)
iqr = q3-q1

upper_bound = q3+1.5*(iqr)
lower_bound = q1-1.5*(iqr)

upper_bound , lower_bound
# Out:
# (fixed acidity             8.800000
#  volatile acidity          0.510000
#  citric acid               0.570000
#  residual sugar           19.850000
#  chlorides                 0.072500
#  free sulfur dioxide      78.000000
#  total sulfur dioxide    256.000000
#  density                   1.001845
#  pH                        3.590000
#  sulphates                 0.760000
#  alcohol                  14.250000
#  quality                   7.500000
#  dtype: float64,
#  fixed acidity            4.800000
#  volatile acidity         0.030000
#  citric acid              0.090000
#  residual sugar          -9.350000
#  chlorides                0.012500
#  free sulfur dioxide    -10.000000
#  total sulfur dioxide    16.000000
#  density                  0.985485
#  pH                       2.790000
#  sulphates                0.200000
#  alcohol                  6.650000
#  quality                  3.500000
#  dtype: float64)

# %%
data = data[~((data<upper_bound))|((data>lower_bound))]

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
plt.figure(figsize = (18,9))
sn.boxplot(data)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
x = data.drop(["quality"] , axis = 1)
y = data['quality']

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
x.isnull().sum()
# Out:
# fixed acidity           23
# volatile acidity         0
# citric acid             78
# residual sugar           0
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     2
# density                  0
# pH                       3
# sulphates                0
# alcohol                  0
# dtype: int64

# %%
x = x.fillna(x.mean())

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
x.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# dtype: int64

# %%
y
# Out:
# 0       6.0
# 1       6.0
# 2       6.0
# 3       6.0
# 6       6.0
#        ...
# 4893    6.0
# 4894    5.0
# 4895    6.0
# 4896    7.0
# 4897    6.0
# Name: quality, Length: 3961, dtype: float64

# %%
y.isnull().sum()
# Out:
# 20

# %%
y = y.fillna(y.mean())

# %%
y.isnull().sum()
# Out:
# 0

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.20 , random_state = 42)

# %%
x_train.shape, x_test.shape
# Out:
# ((3168, 11), (793, 11))

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.18969677,  0.10648903,  1.29630235, ..., -1.63677143,
#         -0.80955275, -0.98162374],
#        [-0.89082345,  0.20392072,  1.12292111, ..., -0.03458343,
#         -0.36875265, -0.89926615],
#        [ 0.91004358, -0.86782791,  0.689468  , ..., -1.03595093,
#          2.18788789,  1.81853418],
#        ...,
#        [-0.05041884, -0.86782791, -0.17743821, ...,  0.36596357,
#         -1.07403281,  0.41845522],
#        [-1.13093905,  0.00905733, -0.00405697, ...,  0.76651057,
#          0.24836748,  0.83024315],
#        [ 0.54987017,  0.78851088, -0.00405697, ..., -0.36837259,
#          0.68916757, -0.32276305]])

# %%
x_test
# Out:
# array([[ 0.42981237,  0.39878411,  1.12292111, ..., -1.10270876,
#         -0.72139273,  1.65381901],
#        [ 3.43125742, -0.38066944,  0.94953987, ...,  0.00414219,
#         -0.19243262,  0.17138246],
#        [ 0.42981237, -0.08837436,  3.46356788, ..., -1.03595093,
#         -0.45691267, -1.55812684],
#        ...,
#        [-1.85128587, -0.38066944, -0.09074759, ...,  2.63572991,
#         -0.98587279,  0.33609763],
#        [-0.05041884,  0.39878411, -0.09074759, ..., -0.56864609,
#         -1.60299292,  0.99495832],
#        [ 0.78998578, -1.45241807,  0.34270552, ...,  0.56623707,
#          0.3365275 ,  0.99495832]])

# %%
y_train
# Out:
# 1594    6.0
# 4153    5.0
# 1320    6.0
# 4739    6.0
# 3423    5.0
#        ...
# 1333    8.0
# 1533    6.0
# 1022    8.0
# 4357    6.0
# 3921    5.0
# Name: quality, Length: 3168, dtype: float64

# %%
x_train.shape
# Out:
# (3168, 11)

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([6.37044746, 5.88344097, 5.3423318 , 5.77444159, 6.22731003,
#        5.79600595, 6.13598602, 5.35385305, 5.70856445, 6.27292984,
#        5.36590965, 5.9837334 , 5.93449973, 5.55947079, 5.4307217 ,
#        5.81091674, 5.36497379, 6.33896775, 5.42518013, 5.26476063,
#        5.53456909, 5.38199763, 6.63765447, 5.80224922, 6.22228131,
#        6.29962702, 6.10795213, 5.69734378, 5.55689458, 6.21722553,
#        5.90381962, 4.98484675, 5.66438745, 5.3710891 , 5.75231872,
#        5.64424583, 6.76585644, 5.87402787, 4.99445815, 6.1274473 ,
#        5.81007798, 6.32430912, 5.85316483, 5.5755903 , 5.08911697,
#        5.41490403, 5.6805017 , 5.90009509, 5.67406577, 5.80372772,
#        6.35944023, 6.61830065, 6.00324222, 6.04127251, 5.64286268,
#        5.77629829, 5.48220489, 6.2494403 , 6.41003445, 5.70333249,
#        5.80201946, 5.14564822, 5.44836165, 5.92546277, 6.4167897 ,
#        5.87797734, 5.58369867, 4.73605666, 6.0495076 , 5.8569691 ,
# ...

# %%
mse_linear = np.mean((y_test-y_pred)**2)

# %%
rmse = np.sqrt(mse_linear)

# %%
rmse
# Out:
# 0.7457510681304221

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_tree = DecisionTreeRegressor(criterion = "squared_error" , max_depth = 5)

# %%
model_tree.fit(x_train , y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
y_pred_tree = model_tree.predict(x_test)

# %%
y_pred_tree
# Out:
# array([6.07982496, 6.22058824, 5.38206318, 5.38206318, 6.22058824,
#        5.92647059, 6.67428571, 5.38206318, 5.61687837, 5.92647059,
#        5.38206318, 6.11069895, 5.61687837, 5.38206318, 5.38206318,
#        6.11069895, 6.17634881, 6.11069895, 5.61687837, 4.97578776,
#        5.95381462, 5.38206318, 6.67428571, 5.38206318, 6.22058824,
#        6.5915493 , 6.5915493 , 5.95381462, 5.61687837, 6.11069895,
#        5.95381462, 5.38206318, 5.58333333, 5.61687837, 6.11069895,
#        5.80786267, 6.07982496, 5.38206318, 4.36842105, 6.11069895,
#        6.22058824, 6.5915493 , 5.38206318, 5.38206318, 5.38206318,
#        5.38206318, 5.38206318, 5.95381462, 5.38206318, 5.92647059,
#        6.5915493 , 6.5915493 , 6.11069895, 6.22058824, 5.61687837,
#        6.11069895, 5.80786267, 6.5915493 , 6.11069895, 5.38206318,
#        6.11069895, 5.38206318, 5.95381462, 5.95381462, 6.17634881,
#        6.22058824, 5.38206318, 4.97632581, 6.5915493 , 6.11069895,
# ...

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize = (24 , 12))
plot_tree(model_tree , filled = True )
# Out:
# [Text(0.5, 0.9166666666666666, 'x[10] <= 0.213\nsquared_error = 0.748\nsamples = 3168\nvalue = 5.865'),
#  Text(0.25, 0.75, 'x[1] <= -0.259\nsquared_error = 0.547\nsamples = 1950\nvalue = 5.579'),
#  Text(0.125, 0.5833333333333334, 'x[10] <= -0.391\nsquared_error = 0.51\nsamples = 916\nvalue = 5.839'),
#  Text(0.0625, 0.4166666666666667, 'x[1] <= -0.527\nsquared_error = 0.471\nsamples = 569\nvalue = 5.729'),
#  Text(0.03125, 0.25, 'x[5] <= -0.372\nsquared_error = 0.484\nsamples = 361\nvalue = 5.831'),
#  Text(0.015625, 0.08333333333333333, 'squared_error = 0.41\nsamples = 120\nvalue = 5.583'),
#  Text(0.046875, 0.08333333333333333, 'squared_error = 0.475\nsamples = 241\nvalue = 5.954'),
#  Text(0.09375, 0.25, 'x[2] <= 0.776\nsquared_error = 0.401\nsamples = 208\nvalue = 5.552'),
#  Text(0.078125, 0.08333333333333333, 'squared_error = 0.412\nsamples = 170\nvalue = 5.617'),
#  Text(0.109375, 0.08333333333333333, 'squared_error = 0.247\nsamples = 38\nvalue = 5.263'),
# ...

# %%
mse = np.mean((y_test - y_pred_tree)**2)

# %%
mse
# Out:
# 0.5824090303156665

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.7631572775749875

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_random = RandomForestRegressor(n_estimators = 100 , max_features = 5)

# %%
model_random.fit(x_train , y_train)
# Out:
# RandomForestRegressor(max_features=5)

# %%
Y_pred_random = model_random.predict(x_test)

# %%
Y_pred_random
# Out:
# array([6.37869323, 5.51738645, 5.24      , 5.47      , 6.42      ,
#        5.64      , 6.43      , 5.22      , 5.47      , 5.81607968,
#        5.28      , 5.93869323, 5.6147729 , 5.39      , 5.29      ,
#        5.97      , 6.08      , 6.61      , 5.56869323, 5.01869323,
#        6.1       , 5.46      , 6.58      , 5.57869323, 5.54      ,
#        6.55      , 6.35      , 5.79      , 5.32869323, 5.97      ,
#        5.79      , 5.26      , 5.39      , 5.42      , 5.73869323,
#        5.33      , 6.45738645, 5.7       , 4.75      , 6.00869323,
#        6.25      , 6.54      , 5.46869323, 5.24869323, 5.3047729 ,
#        5.05      , 5.96      , 5.85      , 5.73      , 5.9       ,
#        6.6       , 6.54      , 6.04      , 5.91      , 5.31      ,
#        6.06      , 5.47      , 6.54      , 6.6       , 5.84      ,
#        5.96869323, 5.65      , 5.94      , 5.8       , 6.69      ,
#        6.39869323, 5.2       , 5.09      , 6.34869323, 5.97      ,
# ...

# %%
mse = np.mean((y_test-Y_pred_random)**2)

# %%
mse
# Out:
# 0.49778650464260227

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.705539867507572

# %%
clf = ([[]])
